# %% [markdown]
# # Modelos de Regresión Lineal
# ## Modelo con datos sumulados
# * y = a + b * x
# * x: 100 valores distribuidos segun distribucion noral N(1.5,2.5)
# * Y = 5 + 1.9 * x + e
# * e estara distribuido segun una N(0,0.8)

# %%
import pandas as pd
import numpy as np
from IPython.display import Image

# %%
x = 1.5 + 2.5 * np.random.randn(100)

# %%
res = 0 + 0.8 * np.random.randn(100)

# %%
y_pred = 5 + 1.9 * x

# %%
y_act = 5 + 1.9 * x + res

# %%
x_list = x.tolist()
y_pred_list = y_pred.tolist()
y_act_list = y_act.tolist()

# %%
data = pd.DataFrame(
    {
     "x" : x_list,
     "y_actual" : y_act_list,
     "y_prediction" : y_pred_list
    }
)

# %%
data.head()
# Out:
#           x  y_actual  y_prediction
# 0 -1.147933  3.431012      2.818928
# 1 -2.184225  1.526540      0.849973
# 2 -0.474876  3.984031      4.097735
# 3 -0.616946  4.094197      3.827803
# 4 -0.276119  3.531242      4.475373

# %%
import matplotlib.pyplot as plt

# %%
y_mean = [np.mean(y_act) for i in range(1,len(x_list) + 1)]

# %%
# %matplotlib inline
plt.plot(x,y_pred)
plt.plot(x,y_mean,"g")
plt.plot(x,y_act,"ro")
plt.title("Actual vs Prediccion")
# Out:
# Text(0.5, 1.0, 'Actual vs Prediccion')

# %%
Image(filename="../imgs/regresion_lineal.png")

# %%
data["SSR"] = (data["y_prediction"] - np.mean(y_act))**2 
data["SSD"] = (data["y_prediction"] - data["y_actual"])**2
data["SST"] = (data["y_actual"] - np.mean(y_act))**2

# %%
data.head()
# Out:
#           x  y_actual  y_prediction        SSR       SSD        SST
# 0 -1.147933  3.431012      2.818928  27.443242  0.374647  21.404923
# 1 -2.184225  1.526540      0.849973  51.949281  0.457744  42.654187
# 2 -0.474876  3.984031      4.097735  15.680196  0.012929  16.593619
# 3 -0.616946  4.094197      3.827803  17.890821  0.070966  15.708228
# 4 -0.276119  3.531242      4.475373  12.832047  0.891384  20.487537

# %%
SSR = sum(data["SSR"])
SSD = sum(data["SSD"])
SST = sum(data["SST"])

# %%
SSR
# Out:
# 2272.8364039729768

# %%
SSD
# Out:
# 70.29531720751623

# %%
SST
# Out:
# 2455.8763955653967

# %%
SSD+SSR
# Out:
# 2343.131721180493

# %%
R2 = SSR / SST

# %%
R2
# Out:
# 0.9254685651432062

# %%
plt.hist(data["SSD"])
# Out:
# (array([53., 16.,  9.,  6.,  4.,  4.,  2.,  4.,  1.,  1.]),
#  array([1.85066094e-04, 3.76512832e-01, 7.52840598e-01, 1.12916836e+00,
#         1.50549613e+00, 1.88182390e+00, 2.25815166e+00, 2.63447943e+00,
#         3.01080720e+00, 3.38713496e+00, 3.76346273e+00]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["y_prediction"] - data["y_actual"])
# Out:
# (array([ 6.,  5., 10., 10., 24., 13., 12., 11.,  5.,  4.]),
#  array([-1.77973032, -1.40776083, -1.03579133, -0.66382184, -0.29185234,
#          0.08011715,  0.45208664,  0.82405614,  1.19602563,  1.56799513,
#          1.93996462]),
#  <a list of 10 Patch objects>)
